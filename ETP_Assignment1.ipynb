# %% [markdown]
# <a href="https://colab.research.google.com/github/B3nzeneKnight/LetsGitStarted/blob/main/ETP_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
import pandas as pd
df=pd.read_csv('gdrive/My Drive/Datasets/breast_cancer_data.csv')

# %%
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# Data Preprocessing

# %%
#X = df.drop(labels=['id','diagnosis','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','texture_worst','perimeter_worst'],axis=1)

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
X=df.drop(['diagnosis'], axis=1)
y=df['diagnosis']

# %%
from sklearn.model_selection import train_test_split
# separate dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(
    X,y,test_size=0.3,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((398, 32), (171, 32))

# %% [markdown]
# Feature Selection

# %%
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(X_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_variance_threshold.py:104: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   self.variances_ = np.nanvar(X, axis=0)
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_variance_threshold.py:112: RuntimeWarning: All-NaN slice encountered
#   self.variances_ = np.nanmin(compare_arr, axis=0)
# VarianceThreshold(threshold=0)

# %%
### Finding non constant features
sum(var_thres.get_support())
# Out:
# 31

# %%
# Lets Find non-constant features 
len(X_train.columns[var_thres.get_support()])
# Out:
# 31

# %%
constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[var_thres.get_support()]]

print(len(constant_columns))
# Out:
# 1

# %%
p=X_train.drop(constant_columns,axis=1)
p
# Out:
#             id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 478     911685       11.490         14.59           73.99      404.9
# 303     892657       10.490         18.61           66.86      334.3
# 155    8711003       12.250         17.94           78.27      460.3
# 186     874217       18.310         18.58          118.60     1041.0
# 101     862722        6.981         13.43           43.79      143.5
# ..         ...          ...           ...             ...        ...
# 277    8911670       18.810         19.98          120.90     1102.0
# 9     84501001       12.460         24.04           83.97      475.9
# 359  901034301        9.436         18.32           59.82      278.6
# 192     875099        9.720         18.22           60.73      288.1
# 559     925291       11.510         23.93           74.52      403.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
p.shape
# Out:
# (398, 31)

# %% [markdown]
# Feature Scaling

# %%
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('gdrive/My Drive/Datasets/breast_cancer_data.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data = df.drop(["id","Unnamed: 32"],axis=1)
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#sns.pairplot(data)

# %% [markdown]
# Normalization

# %% [markdown]
# Linear Regression

# %%
#Using Simple radius to predict via SLR

# %%
df1 = df.loc[ : , 'diagnosis' : 'radius_mean']
df1
# Out:
#     diagnosis  radius_mean
# 0           M        17.99
# 1           M        20.57
# 2           M        19.69
# 3           M        11.42
# 4           M        20.29
# ..        ...          ...
# 564         M        21.56
# 565         M        20.13
# 566         M        16.60
# 567         M        20.60
# 568         B         7.76
#
# [569 rows x 2 columns]

# %%
df1['diagnosis'] = df['diagnosis'].replace(['M'],1)
df1['diagnosis'] = df['diagnosis'].replace(['B'],0)
df1
# Out:
#      diagnosis  radius_mean
# 0            1        17.99
# 1            1        20.57
# 2            1        19.69
# 3            1        11.42
# 4            1        20.29
# ..         ...          ...
# 564          1        21.56
# 565          1        20.13
# 566          1        16.60
# 567          1        20.60
# 568          0         7.76
#
# [569 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
target1= df1.loc[ : , :'diagnosis']
target1

# %%
linear_reg=LinearRegression()
linear_reg.fit(df1[['radius_mean']],df1.diagnosis)
# Out:
# LinearRegression()

# %%
linear_reg.predict([[20.00]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([0.9613025])

# %%
linear_reg.predict([[21.00]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([1.0615491])

# %%
linear_reg.predict([[14.00]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([0.35982292])

# %%
linear_reg.predict([[11.00]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([0.05908312])
